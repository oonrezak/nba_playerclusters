# %%
import pandas as pd
from os import walk
from functools import reduce
from datetime import datetime

# things to add / alter:
    # add column indicating from what csv the rows came from before collate!!
    # change class name to something more general for csv utility functions
    # create a function saves list of dict to csv
        # parameters:
            # specify path name
            # specify alternate column names
    # use walklevel to be able to limit collate csvs per directory level
    # create a method that will retrieve the latest summaries from each directory (within root) then compiles them
        # prompt user if to continue if columns mismatch; show mismatch columns
    # create a method that will join latest summaries in the same subdirec (but different levels) on target column
    # create a method that automatically loads the latest csv in a given directory
    
    # possible parameters: 
        # option to save on different path

class dir_csv():
    
    def __init__(self, direc_path):
        '''Initialize directory to summarize and set file name.
        
        File name: summary with suffix date time.
        
        Parameters:
            direc_path: directory path(s) to summarize.
        '''

        self.dir = direc_path
        now = datetime.now()
        self.date_time = now.strftime("%m-%d-%Y-%H-%M-%S")
    
    def csv_collate(self, fname='Summary'):
        '''Collates all the csv files in the given directory.
        
        Adds the column from where the row data csv came from.
        
        Parameters:
        -----------
            fname: string
                Filename to use for the summary
        '''
        
        list_df = []
        for root, path, files in walk(self.dir):
            for file in files:
                df_tmp = pd.read_csv(root+r'/'+file)
                df_tmp['csv_file'] = [file]*df_tmp.shape[0]
                list_df.append(df_tmp)
        df = reduce(lambda x, y: x.append(y), list_df)
        df = df.drop_duplicates()
        print(fr'Summary File: {self.dir}/{fname}-{self.date_time}.csv')
        df.to_csv(fr'{self.dir}/{fname}-{self.date_time}.csv', index=False)

# %%
dir_csv(r'C:\Users\Nigel\Documents\AIM MSDS\ACS\ACS Project Steph Curry\gsw_games').csv_collate(fname='gsw_summary')
# Out:
# Summary File: C:\Users\Nigel\Documents\AIM MSDS\ACS\ACS Project Steph Curry\gsw_games/gsw_summary-06-25-2019-11-10-20.csv

# %%
df = pd.read_csv(r'C:\Users\Nigel\Documents\AIM MSDS\ACS\ACS Project Steph Curry\gsw_games/gsw_summary-06-25-2019-11-10-20.csv')
# df = df.drop('Unnamed: 0', axis=1)
# df.to_csv(r'ICTjobs/Summary-06-17-2019-14-27-15.csv', index=False)
display(df)
# Out:
#                                                       Q1  \
# 0                                           Start Period
# 1      Jump Ball Jones vs Adams (Green gains possession)
# 2      Thompson Turnover : Bad Pass (1 TO) Steal:Adam...
# 3      George Turnover : Out of Bounds - Bad Pass Tur...
# 4      Curry 3pt Shot: Made (3 PTS) Assist: Durant (1...
# 5                       Adams Floating Jump shot: Missed
# 6                         Schröder Rebound (Off:1 Def:0)
# 7                                George 3pt Shot: Missed
# 8                           Durant Rebound (Off:0 Def:1)
# 9                Durant Driving Layup Shot: Made (2 PTS)
# 10                  Schröder Step Back Jump shot: Missed
# 11                        Schröder Rebound (Off:2 Def:0)
# 12        Adams Layup Shot: Missed Block: Durant (1 BLK)
# 13                           Green Rebound (Off:0 Def:1)
# 7      Felton Turnover : Lost Ball (1 TO) Steal:Green...
# 8                              Thompson 3pt Shot: Missed
# 9                           Felton Rebound (Off:0 Def:1)
# 10                                Noel Hook Shot: Missed
# 11                           Green Rebound (Off:0 Def:7)
# 12                     Thompson Pullup Jump shot: Missed
# 13                                          Team Rebound
# 14                               Stoppage: Out-of-Bounds
# 15                   Green Substitution replaced by Bell
# 16     Diallo Foul: Shooting (1 PF) (2 FTA) (G Petrai...
# 17                    Thompson Free Throw 1 of 2 (7 PTS)
# 18                    Thompson Free Throw 2 of 2 (8 PTS)
# 19         Diallo Layup Shot: Missed Block: Bell (1 BLK)
# 20                                          Team Rebound
# 21                               Stoppage: Out-of-Bounds
# 22                                Team Timeout : Regular
# 23                       Instant Replay - Support Ruling
# 24                 Felton Substitution replaced by Adams
# 25                Noel Substitution replaced by Schröder
# 26                              Adams Layup Shot: Missed
# 27                           Adams Rebound (Off:2 Def:2)
# 28                    Adams Tip Layup Shot: Made (7 PTS)
# 29                Diallo Foul: Personal (2 PF) (Z Zarba)
# ...                                                  ...
# 12871  VanVleet Driving Floating Jump Shot: Made (12 ...
# 12872  Curry Driving Floating Bank Jump Shot: Made (1...
# 12873  Leonard Turnover : Lost Ball (4 TO) Steal:Curr...
# 12874  Curry Running Finger Roll Layup Shot: Made (14...
# 12875                                     Stoppage Other
# 12876          Team Violation : Delay Of Game (S Foster)
# 12877   Green Foul: Personal (2 PF) (2 FTA) (T Brothers)
# 12878                    Siakam Free Throw 1 of 2 Missed
# 12879                                       Team Rebound
# 12880               Gasol Substitution replaced by Green
# 12881                   Siakam Free Throw 2 of 2 (7 PTS)
# 12882  Siakam Foul: Shooting (3 PF) (2 FTA) (T Brothers)
# 12883                   Curry Free Throw 1 of 2 (15 PTS)
# 12884              Powell Substitution replaced by Gasol
# 12885                Cook Substitution replaced by Evans
# 12886             Thompson Substitution replaced by Bell
# 12887            Green Substitution replaced by McKinnie
# 12888                   Curry Free Throw 2 of 2 (16 PTS)
# 12889                                         End Period
# 12890                                                NaN
# 12891                                                NaN
# 12892                                                NaN
# 12893                                                NaN
# 12894                                                NaN
# 12895                                                NaN
# 12896                                                NaN
# 12897                                                NaN
# 12898                                                NaN
# 12899                                                NaN
# 12900                                                NaN
#
#                                                       Q3  \
# 0                                           Start Period
# 1      George Driving Floating Bank Jump Shot: Made (...
# 2          Patterson Violation:Kicked Ball (G Petraitis)
# 3                             Thompson Jump Shot: Missed
# 4                         Schröder Rebound (Off:2 Def:4)
# 5               George Fadeaway Jump Shot: Made (10 PTS)
# 6                                Durant 3pt Shot: Missed
# 7                         Ferguson Rebound (Off:0 Def:2)
# 8                             Patterson 3pt Shot: Missed
# 9                         Ferguson Rebound (Off:1 Def:2)
# 10                            Patterson 3pt Shot: Missed
# 11                           Curry Rebound (Off:0 Def:5)
# 12     Jones Dunk Shot: Made (4 PTS) Assist: Curry (2...
# 13     George 3pt Shot: Made (13 PTS) Assist: Adams (...
# 14                            Thompson Jump Shot: Missed
# 15                                          Team Rebound
# 16                               Stoppage: Out-of-Bounds
# 17                      Green Fadeaway Jump Shot: Missed
# 18                        Schröder Rebound (Off:2 Def:5)
# 19     George Step Back Jump shot: Made (15 PTS) Assi...
# 20                         Curry 3pt Shot: Made (22 PTS)
# 21                               Stoppage: Out-of-Bounds
# 22            Schröder Driving Layup Shot: Made (14 PTS)
# 23                               Durant 3pt Shot: Missed
# 24                           Jones Rebound (Off:2 Def:1)
# 25                     Jones Tip Dunk Shot: Made (6 PTS)
# 26                 Jones Foul: Personal (3 PF) (Z Zarba)
# 27     Patterson 3pt Shot: Made (7 PTS) Assist: Georg...
# 28     Durant Pullup Jump shot: Made (17 PTS) Assist:...
# 29     George 3pt Shot: Made (18 PTS) Assist: Schröde...
# ...                                                  ...
# 12871  McKinnie Foul: Shooting (2 PF) (2 FTA) (S Foster)
# 12872                 Leonard Free Throw 1 of 2 (25 PTS)
# 12873                 Leonard Free Throw 2 of 2 (26 PTS)
# 12874  Bogut Alley Oop Dunk Shot: Made (4 PTS) Assist...
# 12875      Siakam Jump Shot: Missed Block: Green (1 BLK)
# 12876                                       Team Rebound
# 12877                            Stoppage: Out-of-Bounds
# 12878          Powell Turnaround Jump Shot: Made (7 PTS)
# 12879  Curry 3pt Shot: Made (23 PTS) Assist: Green (8...
# 12880          Leonard Driving Layup Shot: Made (28 PTS)
# 12881                             Curry 3pt Shot: Missed
# 12882                       Siakam Rebound (Off:0 Def:4)
# 12883                    Siakam Pullup Jump shot: Missed
# 12884                                       Team Rebound
# 12885                                         End Period
# 12886                                                NaN
# 12887                                                NaN
# 12888                                                NaN
# 12889                                                NaN
# 12890                                                NaN
# 12891                                                NaN
# 12892                                                NaN
# 12893                                                NaN
# 12894                                                NaN
# 12895                                                NaN
# 12896                                                NaN
# 12897                                                NaN
# 12898                                                NaN
# 12899                                                NaN
# 12900                                                NaN
#
#                                                       Q4 csv_file
# 0      Thompson Pullup Jump shot: Made (14 PTS) Assis...    0.csv
# 1      Diallo Turnaround Hook Shot: Made (4 PTS) Assi...    0.csv
# 2           Bell Foul: Shooting (1 PF) (1 FTA) (B Forte)    0.csv
# 3                        Diallo Free Throw 1 of 1 Missed    0.csv
# 4                             Noel Rebound (Off:3 Def:4)    0.csv
# 5                                Felton 3pt Shot: Missed    0.csv
# 6                          Jerebko Rebound (Off:0 Def:1)    0.csv
# 7                                 Cook Jump Shot: Missed    0.csv
# 8                                           Team Rebound    0.csv
# 9                 Noel Foul: Loose Ball (2 PF) (Z Zarba)    0.csv
# 10                   Thompson Driving Layup Shot: Missed    0.csv
# 11                          Diallo Rebound (Off:0 Def:1)    0.csv
# 12     Grant Driving Finger Roll Layup Shot: Made (5 ...    0.csv
# 13              Noel Foul: Personal (3 PF) (G Petraitis)    0.csv
# 14     Livingston Pullup Jump shot: Made (6 PTS) Assi...    0.csv
# 15                              Abrines 3pt Shot: Missed    0.csv
# 16                            Bell Rebound (Off:0 Def:1)    0.csv
# 17     Cook Turnover : Bad Pass (2 TO) Steal:Diallo (...    0.csv
# 18       Jerebko Foul: Shooting (2 PF) (2 FTA) (Z Zarba)    0.csv
# 19                       Grant Free Throw 1 of 2 (6 PTS)    0.csv
# 20            Livingston Substitution replaced by Durant    0.csv
# 21                       Grant Free Throw 2 of 2 (7 PTS)    0.csv
# 22       Abrines Foul: Shooting (1 PF) (2 FTA) (Z Zarba)    0.csv
# 23                     Durant Free Throw 1 of 2 (20 PTS)    0.csv
# 24                     Durant Free Throw 2 of 2 (21 PTS)    0.csv
# 25     Felton Turnover : Out of Bounds - Bad Pass Tur...    0.csv
# 26                             Thompson 3pt Shot: Missed    0.csv
# 27                            Bell Rebound (Off:1 Def:1)    0.csv
# 28                             Thompson 3pt Shot: Missed    0.csv
# 29                         Abrines Rebound (Off:0 Def:2)    0.csv
# ...                                                  ...      ...
# 12871                       Siakam Rebound (Off:2 Def:5)   99.csv
# 12872   Cousins Foul: Personal (5 PF) (2 FTA) (E Malloy)   99.csv
# 12873                 Curry Technical (1 FTA) (E Malloy)   99.csv
# 12874              Leonard Free Throw Technical (32 PTS)   99.csv
# 12875                 Leonard Free Throw 1 of 2 (33 PTS)   99.csv
# 12876                 Leonard Free Throw 2 of 2 (34 PTS)   99.csv
# 12877                             Team Timeout : Regular   99.csv
# 12878  Green Turnover : Out of Bounds - Bad Pass Turn...   99.csv
# 12879                   Instant Replay - Overturn Ruling   99.csv
# 12880           Cook Substitution replaced by Livingston   99.csv
# 12881                          VanVleet 3pt Shot: Missed   99.csv
# 12882                        Green Rebound (Off:2 Def:3)   99.csv
# 12883                          Leonard Hook Shot: Missed   99.csv
# 12884                       Siakam Rebound (Off:3 Def:5)   99.csv
# 12885  Green 3pt Shot: Made (8 PTS) Assist: Siakam (5...   99.csv
# 12886  Iguodala 3pt Shot: Made (8 PTS) Assist: Living...   99.csv
# 12887                             Team Timeout : Regular   99.csv
# 12888              Cousins Substitution replaced by Bell   99.csv
# 12889                             Green 3pt Shot: Missed   99.csv
# 12890                     Iguodala Rebound (Off:1 Def:7)   99.csv
# 12891                                         End Period   99.csv
# 12892                                                NaN   99.csv
# 12893                                                NaN   99.csv
# 12894                                                NaN   99.csv
# 12895                                                NaN   99.csv
# 12896                                                NaN   99.csv
# 12897                                                NaN   99.csv
# 12898                                                NaN   99.csv
# 12899                                                NaN   99.csv
# 12900                                                NaN   99.csv
#
# [12901 rows x 5 columns]
